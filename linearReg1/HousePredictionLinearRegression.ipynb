# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\binita\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\binita\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\binita\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\binita\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\binita\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\binita\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\binita\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\binita\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\binita\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\binita\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\binita\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("homeprices.csv")
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area', fontsize=20)
plt.ylabel('price', fontsize=20)
plt.scatter(df.Area, df.Price, color='red', marker='+')
plt.plot(df.Area, reg.predict(df[['Area']]),color='blue')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['Area']], df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\binita\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
m=reg.coef_

# %%
c= reg.intercept_

# %%
#y=mx + c
y=m*3300 + c
y
#135.78767123 * 3300+ 180616.43835616432
# Out:
# array([628715.75342466])

# %%
d=pd.read_csv('area.csv')
d
# Out:
#      Area
# 0    1000
# 1    1500
# 2    3000
# 3    4500
# 4    6000
# 5    7500
# 6    9000
# 7   10500
# 8   12000
# 9   13500
# 10  15000
# 11  16500
# 12  18000

# %%
p=reg.predict(d)

# %%
d['prices']=p

# %%
d
# Out:
#      Area        prices
# 0    1000  3.164041e+05
# 1    1500  3.842979e+05
# 2    3000  5.879795e+05
# 3    4500  7.916610e+05
# 4    6000  9.953425e+05
# 5    7500  1.199024e+06
# 6    9000  1.402705e+06
# 7   10500  1.606387e+06
# 8   12000  1.810068e+06
# 9   13500  2.013750e+06
# 10  15000  2.217432e+06
# 11  16500  2.421113e+06
# 12  18000  2.624795e+06

# %%
d.to_csv("prediction.csv", index=False)

# %%
d
# Out:
#      Area        prices
# 0    1000  3.164041e+05
# 1    1500  3.842979e+05
# 2    3000  5.879795e+05
# 3    4500  7.916610e+05
# 4    6000  9.953425e+05
# 5    7500  1.199024e+06
# 6    9000  1.402705e+06
# 7   10500  1.606387e+06
# 8   12000  1.810068e+06
# 9   13500  2.013750e+06
# 10  15000  2.217432e+06
# 11  16500  2.421113e+06
# 12  18000  2.624795e+06
